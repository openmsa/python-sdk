# %% [markdown]
# # Show 5 devices

# %% [markdown]
# Basic imports

# %%
from msa_sdk.lookup import Lookup
import json

# %%
lookup = Lookup()
lookup.look_list_device_ids()

devices = json.loads(lookup.content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378                 # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-243995f2923d> in <module>
# ----> 1 lookup = Lookup()
#       2 lookup.look_list_device_ids()
#       3
#       4 devices = json.loads(lookup.content)
#
# /pkg/msa_sdk/lookup.py in __init__(self)
#       9     def __init__(self):
# ...

# %%
print(devices[0:5])
